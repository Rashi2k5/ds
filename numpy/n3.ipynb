# %%
print(9//2)
# Out:
# 4

# %%
3*1**3
# Out:
# 3

# %%
print("abcefd".replace("cd",'12'))
# Out:
# abcefd

# %%
x = [1,2,3,4,5,6,7]

print(x.pop(1))
# Out:
# 2

# %%
if 4+5 == 7:
    print("true")
else:
    print("false")
print("true")
# Out:
# false
# true
