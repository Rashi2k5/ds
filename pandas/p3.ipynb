# %%
import pandas as pd

# %%
x = [1,2,3,4,4,5]
a = pd.Series(x)
print(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    4
# 5    5
# dtype: int64

# %%
# data frame

# %%
b = pd.DataFrame(x)
print(b)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  4
# 5  5

# %%
dic = {"name" : ["shyam","ram","naam"], "class" : [3,2,4],"subject": ["hindi","english", "maths"]}
c = pd.DataFrame(dic)
print(c)
# Out:
#     name  class  subject
# 0  shyam      3    hindi
# 1    ram      2  english
# 2   naam      4    maths

# %%
print(c["name"][1])
# Out:
# ram
